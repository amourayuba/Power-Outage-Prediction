# %%
import pandas as pd
import numpy as np
import ftplib
import requests
import matplotlib.pyplot as plt
import os
import re
from datetime import datetime

# %%
# connect to the server
ftp = ftplib.FTP('ftp.ncdc.noaa.gov', timeout=30) #pass the url without protocol
ftp.login() #pass credentials if anonymous access is not allowed

# switch to the directory containing the data
ftp.cwd('/pub/data/swdi/database-csv/v2/')
ftp.pwd()

httpurl = 'https://www.ncei.noaa.gov/pub/data/swdi/database-csv/v2/'
# get the list of files in this ftp dir
all_files= ftp.nlst()

# %%
#all_files

# %%
pattern = r"meso-[0-9]{4}\."
meso_files = [i for i in all_files if bool(re.match(pattern, i))]
meso_files.sort()
print(meso_files)
# Out:
# ['meso-1995.csv.gz', 'meso-1996.csv.gz', 'meso-1997.csv.gz', 'meso-1998.csv.gz', 'meso-1999.csv.gz', 'meso-2000.csv.gz', 'meso-2001.csv.gz', 'meso-2002.csv.gz', 'meso-2003.csv.gz', 'meso-2004.csv.gz', 'meso-2005.csv.gz', 'meso-2006.csv.gz', 'meso-2007.csv.gz', 'meso-2008.csv.gz', 'meso-2009.csv.gz', 'meso-2010.csv.gz']

# %%
query_parameters = {"downloadformat": "csv"}
response = requests.get(httpurl+meso_files[-1], params=query_parameters)

# %%
response.url
# Out:
# 'https://www.ncei.noaa.gov/pub/data/swdi/database-csv/v2/meso-2010.csv.gz?downloadformat=csv'

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
with open(r'../weather_data/meso/' 
              + meso_files[-1], "wb") as file:
    file.write(response.content)

# %%
meso_2010 = pd.read_csv(r'../weather_data/meso/' 
              + meso_files[-1], skiprows=2, parse_dates=['#ZTIME'])
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6

# %%
pip install reverse-geocoder
# Out:
# Requirement already satisfied: reverse-geocoder in c:\users\hatice\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\hatice\anaconda3\lib\site-packages (from reverse-geocoder) (1.24.3)
# Requirement already satisfied: scipy>=0.17.1 in c:\users\hatice\anaconda3\lib\site-packages (from reverse-geocoder) (1.11.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import reverse_geocoder as rg

# %%
meso_2010 = pd.read_csv('../weather_data/meso/meso-2010.csv', skiprows=2)

# %%
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6

# %%
# first add a new column containing both lat and lon
locations = list(zip(meso_2010['LAT'],meso_2010['LON']))
meso_2010['location'] = locations

# then get the county (admin2) into a new column
address = rg.search(locations)
meso_2010['county'] = [x['admin2'] for x in address]
meso_2010['state'] = [x['admin1'] for x in address]
# Out:
# Loading formatted geocoded file...

# %%
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6

# %%
def string_split_first(s):
    parts = s.split(' ', 1)
    return parts[0]
def string_split_second(s):
    parts = s.split(' ', 1)
    return parts[1]

# %%
def date_to_string(d):
    return d.strftime('%Y-%m-%d %H:%M:%S')

# %%
meso_2010['DATE_STRING']=meso_2010['#ZTIME'].apply(date_to_string)

# %%
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR  \
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6
#
#            DATE_STRING
# 0  2010-01-01 00:00:25
# 1  2010-01-01 00:00:50
# 2  2010-01-01 00:00:50
# 3  2010-01-01 00:00:50
# 4  2010-01-01 00:00:50

# %%
meso_2010['DATE']=meso_2010['DATE_STRING'].apply(string_split_first)

# %%
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR  \
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6
#
#            DATE_STRING        DATE
# 0  2010-01-01 00:00:25  2010-01-01
# 1  2010-01-01 00:00:50  2010-01-01
# 2  2010-01-01 00:00:50  2010-01-01
# 3  2010-01-01 00:00:50  2010-01-01
# 4  2010-01-01 00:00:50  2010-01-01

# %%
meso_2010['TIME']=meso_2010['DATE_STRING'].apply(string_split_second)

# %%
meso_2010.head()
# Out:
#                #ZTIME        LON       LAT WSR_ID CELL_ID CELL_TYPE  RANGE  \
# 0 2010-01-01 00:00:25  -95.20293  32.06692   KSHV      M2   UNC SHR     73
# 1 2010-01-01 00:00:50 -109.95558  45.20309   KBLX     NaN   UNC SHR     69
# 2 2010-01-01 00:00:50 -110.10992  45.12659   KBLX     NaN   UNC SHR     77
# 3 2010-01-01 00:00:50 -109.65312  44.74401   KBLX     NaN   UNC SHR     80
# 4 2010-01-01 00:00:50 -110.00047  45.99929   KBLX     NaN   UNC SHR     59
#
#    AZIMUTH  BASE_HEIGHT  TOP_HEIGHT  HEIGHT  RADIUS  AZDIA  SHEAR  \
# 0      252          7.7         7.7     7.7     1.8    4.1      5
# 1      236         14.3        14.3    14.3     2.3    2.9     11
# 2      236         16.6        16.6    16.6    13.4    3.2     10
# 3      214         17.3        17.3    17.3    10.4    2.6      9
# 4      279         18.3        18.3    18.3     1.2    3.7      6
#
#            DATE_STRING        DATE      TIME
# 0  2010-01-01 00:00:25  2010-01-01  00:00:25
# 1  2010-01-01 00:00:50  2010-01-01  00:00:50
# 2  2010-01-01 00:00:50  2010-01-01  00:00:50
# 3  2010-01-01 00:00:50  2010-01-01  00:00:50
# 4  2010-01-01 00:00:50  2010-01-01  00:00:50
