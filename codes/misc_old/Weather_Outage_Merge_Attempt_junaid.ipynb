# %%
# install reverse-geocoder https://pypi.org/project/reverse_geocoder/
# !pip install reverse-geocoder
# Out:
# Requirement already satisfied: reverse-geocoder in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_24/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.11.0 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_24/lib/python3.11/site-packages (from reverse-geocoder) (1.26.4)
# Requirement already satisfied: scipy>=0.17.1 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_24/lib/python3.11/site-packages (from reverse-geocoder) (1.12.0)

# %%
# import useful libraries
import pandas as pd
import numpy as np
import reverse_geocoder as rg

# enable copy on write (default in pandas 3.0)
pd.options.mode.copy_on_write = True

# %%
# powercut data
power_2019 = pd.read_excel('../power_data/2019_Annual_Summary.xls', skiprows=1)
# Out:
# WARNING *** file size (96452) not 512 + multiple of sector size (512)

# %%
# lightning data
lightning_2019 = pd.read_csv('../weather_data/lightning/tvs-tiles-2019.csv', skiprows=2)

# %%
lightning_2019.head()
# Out:
#       #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT
# 0  20190101      -97.6       27.0            1
# 1  20190101     -152.3       60.9            3
# 2  20190101      -73.2       43.0            1
# 3  20190101     -135.7       57.0            1
# 4  20190101      -86.2       34.9            1

# %% [markdown]
# ## Reverse Geocoding
#
# Reverse geocoding is getting address (or county, state) from lat-lon.
#
# We use the [reverse_geocoder](https://github.com/thampiman/reverse-geocoder) library
#  It gives us county (admin 2) and state (admin 1) info too!

# %%
# first add a new column containing both lat and lon
locations = list(zip(lightning_2019['CENTERLAT'],lightning_2019['CENTERLON']))
lightning_2019['location'] = locations

# then get the county (admin2) into a new column
address = rg.search(locations)
lightning_2019['county'] = [x['admin2'] for x in address]
lightning_2019['state'] = [x['admin1'] for x in address]
# Out:
# Loading formatted geocoded file...

# %%
# lets see now how it looks
lightning_2019
# Out:
#           #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT        location  \
# 0      20190101      -97.6       27.0            1   (27.0, -97.6)
# 1      20190101     -152.3       60.9            3  (60.9, -152.3)
# 2      20190101      -73.2       43.0            1   (43.0, -73.2)
# 3      20190101     -135.7       57.0            1  (57.0, -135.7)
# 4      20190101      -86.2       34.9            1   (34.9, -86.2)
# ...         ...        ...        ...          ...             ...
# 56890  20191231     -123.6       47.4            1  (47.4, -123.6)
# 56891  20191231     -123.7       47.5            1  (47.5, -123.7)
# 56892  20191231     -123.0       47.8            1  (47.8, -123.0)
# 56893  20191231     -123.7       47.8            4  (47.8, -123.7)
# 56894  20191231     -122.8       45.8            1  (45.8, -122.8)
#
#                         county       state
# 0                Kenedy County       Texas
# 1      Kenai Peninsula Borough      Alaska
# 2            Bennington County     Vermont
# 3       Sitka City and Borough      Alaska
# 4               Madison County     Alabama
# ...                        ...         ...
# 56890      Grays Harbor County  Washington
# 56891      Grays Harbor County  Washington
# 56892            Kitsap County  Washington
# 56893           Clallam County  Washington
# 56894          Columbia County      Oregon
#
# [56895 rows x 7 columns]

# %% [markdown]
# ## Filtering only Severe Weather

# %%
# filter only severe weather
sev_weather_power_2019 = power_2019[power_2019['Event Type'].str.contains(r'Severe Weather', regex=True)]

# %%
sev_weather_power_2019
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 1     January       01/06/2019         03:00:00          01/09/2019
# 2     January       01/06/2019         17:56:00          01/06/2019
# 3     January       01/06/2019         01:00:00          01/06/2019
# 8     January       01/12/2019         11:30:00          01/13/2019
# 9     January       01/12/2019         11:30:00             Unknown
# ..        ...              ...              ...                 ...
# 246  November       11/01/2019         01:15:00          11/02/2019
# 247  November       11/01/2019         02:41:00             Unknown
# 255  November       11/20/2019         09:49:00          11/20/2019
# 259  November       11/26/2019         18:07:00          11/27/2019
# 261  November       11/27/2019         12:00:00          11/30/2019
#
#     Time of Restoration                                      Area Affected  \
# 1              07:00:00                                        Washington:
# 2              21:52:00                     California: Sacramento County;
# 3              12:00:00  Washington: King County, Thurston County, Pier...
# 8              22:00:00  Missouri: Jackson County; Kansas: Johnson County;
# 9               Unknown                                Missouri: Nebraska:
# ..                  ...                                                ...
# 246            21:30:00  Connecticut: Maine: Massachusetts: Rhode Islan...
# 247             Unknown                           New York: Broome County;
# 255            15:20:00  California: Colusa County, Lake County, Mendoc...
# 259            12:27:00                                        California:
# 261            02:00:00  Michigan: Tuscola County, Sanilac County, Huro...
#
#     NERC Region                                     Alert Criteria  \
# 1          WECC  Loss of electric service to more than 50,000 c...
# 2          WECC  Loss of electric service to more than 50,000 c...
# 3          WECC  Loss of electric service to more than 50,000 c...
# 8        SPP RE  Loss of electric service to more than 50,000 c...
# 9          SERC  Loss of electric service to more than 50,000 c...
# ..          ...                                                ...
# 246        NPCC  Loss of electric service to more than 50,000 c...
# 247        NPCC  Loss of electric service to more than 50,000 c...
# 255        WECC  Loss of electric service to more than 50,000 c...
# 259        WECC  Loss of electric service to more than 50,000 c...
# 261          RF  Loss of electric service to more than 50,000 c...
#
#                                    Event Type Demand Loss (MW)  \
# 1                              Severe Weather              230
# 2                              Severe Weather              300
# 3                              Severe Weather          Unknown
# 8                              Severe Weather          Unknown
# 9                              Severe Weather          Unknown
# ..                                        ...              ...
# 246                            Severe Weather          Unknown
# 247                            Severe Weather          Unknown
# 255  Severe Weather/Transmission Interruption              178
# 259                            Severe Weather              300
# 261                            Severe Weather               30
#
#     Number of Customers Affected
# 1                         230000
# 2                          90382
# 3                         230000
# 8                         112530
# 9                         116600
# ..                           ...
# 246                        80066
# 247                        66325
# 255                        54000
# 259                        93000
# 261                       107000
#
# [92 rows x 11 columns]

# %% [markdown]
# # Clean the Unknown Entries from Dates

# %%
# convert to string datatype
sev_weather_power_2019['Date of Restoration'] = sev_weather_power_2019['Date of Restoration'].astype(str)
sev_weather_power_2019['Area Affected'] = sev_weather_power_2019['Area Affected'].astype(str)
lightning_2019['county'] = lightning_2019['county'].astype(str)
lightning_2019['state'] = lightning_2019['state'].astype(str)

# %%
# drop rows when 'county' column is empty, and lat lon is outside US range
# first we create a mask for nonempty county and continental US range lat 24 to 50 and lon -125 to -66
lightning_mask = (lightning_2019['county']!='') & (lightning_2019['CENTERLAT']>=24) & (lightning_2019['CENTERLAT']<=50) &(lightning_2019['CENTERLON']>=-125) &(lightning_2019['CENTERLON']<=-66)

lightning_2019 = lightning_2019[lightning_mask]

lightning_2019
# Out:
#           #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT        location  \
# 0      20190101      -97.6       27.0            1   (27.0, -97.6)
# 2      20190101      -73.2       43.0            1   (43.0, -73.2)
# 4      20190101      -86.2       34.9            1   (34.9, -86.2)
# 5      20190101      -83.7       35.6            1   (35.6, -83.7)
# 6      20190101      -83.6       35.6            1   (35.6, -83.6)
# ...         ...        ...        ...          ...             ...
# 56890  20191231     -123.6       47.4            1  (47.4, -123.6)
# 56891  20191231     -123.7       47.5            1  (47.5, -123.7)
# 56892  20191231     -123.0       47.8            1  (47.8, -123.0)
# 56893  20191231     -123.7       47.8            4  (47.8, -123.7)
# 56894  20191231     -122.8       45.8            1  (45.8, -122.8)
#
#                     county       state
# 0            Kenedy County       Texas
# 2        Bennington County     Vermont
# 4           Madison County     Alabama
# 5            Sevier County   Tennessee
# 6            Sevier County   Tennessee
# ...                    ...         ...
# 56890  Grays Harbor County  Washington
# 56891  Grays Harbor County  Washington
# 56892        Kitsap County  Washington
# 56893       Clallam County  Washington
# 56894      Columbia County      Oregon
#
# [55463 rows x 7 columns]

# %%
sev_weather_power_2019_copy = sev_weather_power_2019.copy()

# when Date of Restoration is Unknown, copy Date of Event
sev_weather_power_2019_copy.loc[sev_weather_power_2019_copy['Date of Restoration'] == 'Unknown', 'Date of Restoration'] = sev_weather_power_2019_copy.loc[sev_weather_power_2019_copy['Date of Restoration'] == 'Unknown', 'Date Event Began']

# %%
sev_weather_power_2019_copy
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 1     January       01/06/2019         03:00:00          01/09/2019
# 2     January       01/06/2019         17:56:00          01/06/2019
# 3     January       01/06/2019         01:00:00          01/06/2019
# 8     January       01/12/2019         11:30:00          01/13/2019
# 9     January       01/12/2019         11:30:00          01/12/2019
# ..        ...              ...              ...                 ...
# 246  November       11/01/2019         01:15:00          11/02/2019
# 247  November       11/01/2019         02:41:00          11/01/2019
# 255  November       11/20/2019         09:49:00          11/20/2019
# 259  November       11/26/2019         18:07:00          11/27/2019
# 261  November       11/27/2019         12:00:00          11/30/2019
#
#     Time of Restoration                                      Area Affected  \
# 1              07:00:00                                        Washington:
# 2              21:52:00                     California: Sacramento County;
# 3              12:00:00  Washington: King County, Thurston County, Pier...
# 8              22:00:00  Missouri: Jackson County; Kansas: Johnson County;
# 9               Unknown                                Missouri: Nebraska:
# ..                  ...                                                ...
# 246            21:30:00  Connecticut: Maine: Massachusetts: Rhode Islan...
# 247             Unknown                           New York: Broome County;
# 255            15:20:00  California: Colusa County, Lake County, Mendoc...
# 259            12:27:00                                        California:
# 261            02:00:00  Michigan: Tuscola County, Sanilac County, Huro...
#
#     NERC Region                                     Alert Criteria  \
# 1          WECC  Loss of electric service to more than 50,000 c...
# 2          WECC  Loss of electric service to more than 50,000 c...
# 3          WECC  Loss of electric service to more than 50,000 c...
# 8        SPP RE  Loss of electric service to more than 50,000 c...
# 9          SERC  Loss of electric service to more than 50,000 c...
# ..          ...                                                ...
# 246        NPCC  Loss of electric service to more than 50,000 c...
# 247        NPCC  Loss of electric service to more than 50,000 c...
# 255        WECC  Loss of electric service to more than 50,000 c...
# 259        WECC  Loss of electric service to more than 50,000 c...
# 261          RF  Loss of electric service to more than 50,000 c...
#
#                                    Event Type Demand Loss (MW)  \
# 1                              Severe Weather              230
# 2                              Severe Weather              300
# 3                              Severe Weather          Unknown
# 8                              Severe Weather          Unknown
# 9                              Severe Weather          Unknown
# ..                                        ...              ...
# 246                            Severe Weather          Unknown
# 247                            Severe Weather          Unknown
# 255  Severe Weather/Transmission Interruption              178
# 259                            Severe Weather              300
# 261                            Severe Weather               30
#
#     Number of Customers Affected
# 1                         230000
# 2                          90382
# 3                         230000
# 8                         112530
# 9                         116600
# ..                           ...
# 246                        80066
# 247                        66325
# 255                        54000
# 259                        93000
# 261                       107000
#
# [92 rows x 11 columns]

# %% [markdown]
# ## Rename for easy naming

# %%
df1 = lightning_2019.copy()
df2 = sev_weather_power_2019_copy.copy()

# %%
# convert string to datetime
# add format='mixed' if you get an error
# some datasets have times in multiple formats at once
df1['#ZDAY'] = pd.to_datetime(df1['#ZDAY'], format='%Y%m%d')
df2['Date Event Began'] = pd.to_datetime(df2['Date Event Began'], format='%m/%d/%Y')
df2['Date of Restoration'] = pd.to_datetime(df2['Date of Restoration'], format='%m/%d/%Y')

# %% [markdown]
# ## Inspecting df1 and df2

# %%
df1['county'] = df1['county'].astype(str)
df1['state'] = df1['state'].astype(str)

# %%
df2['Area Affected'] = df2['Area Affected'].astype(str)
df2['Month'] = df2['Month'].astype(str)

# %% [markdown]
# ## Lightning date to Power cut date
#
# Here we filter those columns from power data which have some lightning observation. Mostly it gives us the same data since the lightning data is very vast and encorporates all dates in powercut.

# %%
# Filter df2 based on whether #ZDAY falls within the range of Date Event Began
df2_filtered = df2[df2['Date Event Began'].isin(df1['#ZDAY'])]

# %%
df2_filtered
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 1     January       2019-01-06         03:00:00          2019-01-09
# 2     January       2019-01-06         17:56:00          2019-01-06
# 3     January       2019-01-06         01:00:00          2019-01-06
# 8     January       2019-01-12         11:30:00          2019-01-13
# 9     January       2019-01-12         11:30:00          2019-01-12
# ..        ...              ...              ...                 ...
# 246  November       2019-11-01         01:15:00          2019-11-02
# 247  November       2019-11-01         02:41:00          2019-11-01
# 255  November       2019-11-20         09:49:00          2019-11-20
# 259  November       2019-11-26         18:07:00          2019-11-27
# 261  November       2019-11-27         12:00:00          2019-11-30
#
#     Time of Restoration                                      Area Affected  \
# 1              07:00:00                                        Washington:
# 2              21:52:00                     California: Sacramento County;
# 3              12:00:00  Washington: King County, Thurston County, Pier...
# 8              22:00:00  Missouri: Jackson County; Kansas: Johnson County;
# 9               Unknown                                Missouri: Nebraska:
# ..                  ...                                                ...
# 246            21:30:00  Connecticut: Maine: Massachusetts: Rhode Islan...
# 247             Unknown                           New York: Broome County;
# 255            15:20:00  California: Colusa County, Lake County, Mendoc...
# 259            12:27:00                                        California:
# 261            02:00:00  Michigan: Tuscola County, Sanilac County, Huro...
#
#     NERC Region                                     Alert Criteria  \
# 1          WECC  Loss of electric service to more than 50,000 c...
# 2          WECC  Loss of electric service to more than 50,000 c...
# 3          WECC  Loss of electric service to more than 50,000 c...
# 8        SPP RE  Loss of electric service to more than 50,000 c...
# 9          SERC  Loss of electric service to more than 50,000 c...
# ..          ...                                                ...
# 246        NPCC  Loss of electric service to more than 50,000 c...
# 247        NPCC  Loss of electric service to more than 50,000 c...
# 255        WECC  Loss of electric service to more than 50,000 c...
# 259        WECC  Loss of electric service to more than 50,000 c...
# 261          RF  Loss of electric service to more than 50,000 c...
#
#                                    Event Type Demand Loss (MW)  \
# 1                              Severe Weather              230
# 2                              Severe Weather              300
# 3                              Severe Weather          Unknown
# 8                              Severe Weather          Unknown
# 9                              Severe Weather          Unknown
# ..                                        ...              ...
# 246                            Severe Weather          Unknown
# 247                            Severe Weather          Unknown
# 255  Severe Weather/Transmission Interruption              178
# 259                            Severe Weather              300
# 261                            Severe Weather               30
#
#     Number of Customers Affected
# 1                         230000
# 2                          90382
# 3                         230000
# 8                         112530
# 9                         116600
# ..                           ...
# 246                        80066
# 247                        66325
# 255                        54000
# 259                        93000
# 261                       107000
#
# [91 rows x 11 columns]

# %% [markdown]
# We check if the power outage dataset has a county information in the Area Affected or not

# %% [markdown]
# Find columns which do not have any county info. On those columns check states. Have boolean columns which say whether did county match (accurate) or state match

# %%
# get all US states
county = pd.read_csv("../extras/uscounties.csv", index_col=0)
county['county'] = county['county'].astype(str)
county
# Out:
#            state      lat       lng  population              location  \
# 0     California  34.3219 -118.2247     9936690  (34.3219, -118.2247)
# 1       Illinois  41.8401  -87.8168     5225367   (41.8401, -87.8168)
# 2          Texas  29.8578  -95.3938     4726177   (29.8578, -95.3938)
# 3        Arizona  33.3490 -112.4915     4430871   (33.349, -112.4915)
# 4     California  33.0343 -116.7351     3289701  (33.0343, -116.7351)
# ...          ...      ...       ...         ...                   ...
# 3139    Nebraska  41.9128  -99.9768         384   (41.9128, -99.9768)
# 3140       Texas  33.6165 -100.2558         216  (33.6165, -100.2558)
# 3141       Texas  26.9285  -97.7017         116   (26.9285, -97.7017)
# 3142       Texas  31.8493 -103.5800          96    (31.8493, -103.58)
# 3143      Hawaii  21.1709 -156.9475          50  (21.1709, -156.9475)
#
#                   county
# 0     Los Angeles County
# 1            Cook County
# 2          Harris County
# 3        Maricopa County
# 4       San Diego County
# ...                  ...
# 3139       Blaine County
# 3140         King County
# 3141       Kenedy County
# 3142       Loving County
# 3143         Maui County
#
# [3144 rows x 6 columns]

# %%
df2_filtered_copy = df2_filtered.copy()

df2_filtered_copy["county_info_area_affected"] = df2_filtered_copy.apply(lambda row: any(counti in row['Area Affected'] for counti in county['county']) , axis=1)

# %%
df2_filtered_copy
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 1     January       2019-01-06         03:00:00          2019-01-09
# 2     January       2019-01-06         17:56:00          2019-01-06
# 3     January       2019-01-06         01:00:00          2019-01-06
# 8     January       2019-01-12         11:30:00          2019-01-13
# 9     January       2019-01-12         11:30:00          2019-01-12
# ..        ...              ...              ...                 ...
# 246  November       2019-11-01         01:15:00          2019-11-02
# 247  November       2019-11-01         02:41:00          2019-11-01
# 255  November       2019-11-20         09:49:00          2019-11-20
# 259  November       2019-11-26         18:07:00          2019-11-27
# 261  November       2019-11-27         12:00:00          2019-11-30
#
#     Time of Restoration                                      Area Affected  \
# 1              07:00:00                                        Washington:
# 2              21:52:00                     California: Sacramento County;
# 3              12:00:00  Washington: King County, Thurston County, Pier...
# 8              22:00:00  Missouri: Jackson County; Kansas: Johnson County;
# 9               Unknown                                Missouri: Nebraska:
# ..                  ...                                                ...
# 246            21:30:00  Connecticut: Maine: Massachusetts: Rhode Islan...
# 247             Unknown                           New York: Broome County;
# 255            15:20:00  California: Colusa County, Lake County, Mendoc...
# 259            12:27:00                                        California:
# 261            02:00:00  Michigan: Tuscola County, Sanilac County, Huro...
#
#     NERC Region                                     Alert Criteria  \
# 1          WECC  Loss of electric service to more than 50,000 c...
# 2          WECC  Loss of electric service to more than 50,000 c...
# 3          WECC  Loss of electric service to more than 50,000 c...
# 8        SPP RE  Loss of electric service to more than 50,000 c...
# 9          SERC  Loss of electric service to more than 50,000 c...
# ..          ...                                                ...
# 246        NPCC  Loss of electric service to more than 50,000 c...
# 247        NPCC  Loss of electric service to more than 50,000 c...
# 255        WECC  Loss of electric service to more than 50,000 c...
# 259        WECC  Loss of electric service to more than 50,000 c...
# 261          RF  Loss of electric service to more than 50,000 c...
#
#                                    Event Type Demand Loss (MW)  \
# 1                              Severe Weather              230
# 2                              Severe Weather              300
# 3                              Severe Weather          Unknown
# 8                              Severe Weather          Unknown
# 9                              Severe Weather          Unknown
# ..                                        ...              ...
# 246                            Severe Weather          Unknown
# 247                            Severe Weather          Unknown
# 255  Severe Weather/Transmission Interruption              178
# 259                            Severe Weather              300
# 261                            Severe Weather               30
#
#     Number of Customers Affected  county_info_area_affected
# 1                         230000                      False
# 2                          90382                       True
# 3                         230000                       True
# 8                         112530                       True
# 9                         116600                      False
# ..                           ...                        ...
# 246                        80066                      False
# 247                        66325                       True
# 255                        54000                       True
# 259                        93000                      False
# 261                       107000                       True
#
# [91 rows x 12 columns]

# %% [markdown]
# here we now check if the date rows match between the two dataframes

# %%
# Merge df1 with the filtered df2 based on the condition that is county in area is true and the lightning date matches the power cut date
# it is an inner join which means give only those that are in the intersection
# therefore only those dates that are in lightning and that are in powercuts will be searched out
# remember this is still a match on dates, and it remains to match on area/county

#merged_df = pd.merge(df1, df2_filtered_copy, how='inner', left_on='#ZDAY', right_on='Date Event Began')

left_merged_df = pd.merge(df1, df2_filtered_copy, how='left', left_on='#ZDAY', right_on='Date Event Began', indicator=True)

# %%
inner_merged_df = left_merged_df[left_merged_df['_merge'] !='left_only']

# %%
inner_merged_df
# Out:
#            #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT        location  \
# 124   2019-01-06     -120.0       35.0            1  (35.0, -120.0)
# 125   2019-01-06     -120.0       35.0            1  (35.0, -120.0)
# 126   2019-01-06     -120.0       35.0            1  (35.0, -120.0)
# 127   2019-01-06     -123.4       47.3            1  (47.3, -123.4)
# 128   2019-01-06     -123.4       47.3            1  (47.3, -123.4)
# ...          ...        ...        ...          ...             ...
# 61010 2019-11-27      -71.7       42.2            1   (42.2, -71.7)
# 61011 2019-11-27      -79.2       42.4            3   (42.4, -79.2)
# 61012 2019-11-27      -79.2       42.5            1   (42.5, -79.2)
# 61013 2019-11-27      -71.9       42.5            1   (42.5, -71.9)
# 61014 2019-11-27      -83.5       42.8            1   (42.8, -83.5)
#
#                      county          state     Month Date Event Began  \
# 124    Santa Barbara County     California   January       2019-01-06
# 125    Santa Barbara County     California   January       2019-01-06
# 126    Santa Barbara County     California   January       2019-01-06
# 127     Grays Harbor County     Washington   January       2019-01-06
# 128     Grays Harbor County     Washington   January       2019-01-06
# ...                     ...            ...       ...              ...
# 61010      Worcester County  Massachusetts  November       2019-11-27
# 61011     Chautauqua County       New York  November       2019-11-27
# 61012     Chautauqua County       New York  November       2019-11-27
# 61013      Worcester County  Massachusetts  November       2019-11-27
# 61014        Oakland County       Michigan  November       2019-11-27
#
#       Time Event Began Date of Restoration Time of Restoration  \
# 124           03:00:00          2019-01-09            07:00:00
# 125           17:56:00          2019-01-06            21:52:00
# 126           01:00:00          2019-01-06            12:00:00
# 127           03:00:00          2019-01-09            07:00:00
# 128           17:56:00          2019-01-06            21:52:00
# ...                ...                 ...                 ...
# 61010         12:00:00          2019-11-30            02:00:00
# 61011         12:00:00          2019-11-30            02:00:00
# 61012         12:00:00          2019-11-30            02:00:00
# 61013         12:00:00          2019-11-30            02:00:00
# 61014         12:00:00          2019-11-30            02:00:00
#
#                                            Area Affected NERC Region  \
# 124                                          Washington:        WECC
# 125                       California: Sacramento County;        WECC
# 126    Washington: King County, Thurston County, Pier...        WECC
# 127                                          Washington:        WECC
# 128                       California: Sacramento County;        WECC
# ...                                                  ...         ...
# 61010  Michigan: Tuscola County, Sanilac County, Huro...          RF
# 61011  Michigan: Tuscola County, Sanilac County, Huro...          RF
# 61012  Michigan: Tuscola County, Sanilac County, Huro...          RF
# 61013  Michigan: Tuscola County, Sanilac County, Huro...          RF
# 61014  Michigan: Tuscola County, Sanilac County, Huro...          RF
#
#                                           Alert Criteria      Event Type  \
# 124    Loss of electric service to more than 50,000 c...  Severe Weather
# 125    Loss of electric service to more than 50,000 c...  Severe Weather
# 126    Loss of electric service to more than 50,000 c...  Severe Weather
# 127    Loss of electric service to more than 50,000 c...  Severe Weather
# 128    Loss of electric service to more than 50,000 c...  Severe Weather
# ...                                                  ...             ...
# 61010  Loss of electric service to more than 50,000 c...  Severe Weather
# 61011  Loss of electric service to more than 50,000 c...  Severe Weather
# 61012  Loss of electric service to more than 50,000 c...  Severe Weather
# 61013  Loss of electric service to more than 50,000 c...  Severe Weather
# 61014  Loss of electric service to more than 50,000 c...  Severe Weather
#
#       Demand Loss (MW) Number of Customers Affected county_info_area_affected  \
# 124                230                       230000                     False
# 125                300                        90382                      True
# 126            Unknown                       230000                      True
# 127                230                       230000                     False
# 128                300                        90382                      True
# ...                ...                          ...                       ...
# 61010               30                       107000                      True
# 61011               30                       107000                      True
# 61012               30                       107000                      True
# 61013               30                       107000                      True
# 61014               30                       107000                      True
#
#       _merge
# 124     both
# 125     both
# 126     both
# 127     both
# 128     both
# ...      ...
# 61010   both
# 61011   both
# 61012   both
# 61013   both
# 61014   both
#
# [24635 rows x 20 columns]

# %% [markdown]
# ## Now we match county
#
# and we match state only when no county info present.
#
# Caveat: some counties have same names in different states, so need to check state too

# %%
filtered_df = left_merged_df[left_merged_df.apply(lambda row: (row['_merge'] == 'both') and(str(row['county']) in str(row['Area Affected']) and str(row['state']) in str(row['Area Affected'])) or ((str(row['state']) in str(row['Area Affected']))and (not row['county_info_area_affected'])), axis=1)]

# %% [markdown]
# ## Now we add the power outage yes/no to lightning
#
# Once we have the filtered_df, we can use it to go back to the lightning data, and add the column which says whether power outage happened or not
#
# As a rough estimate, for the year 2019,
#  55000 rows of lightning data, we got about 3000 power outages.
#
# One can say that the total power outage is 92, then how are we getting 3000 outages, the answer is that these are not distinct outages, rather these are distinct lightning events.
#
# So from about 55000 lightning events, 3000 of them gave rise to power outages, and multiple lightnings may be responsible for a single outage.

# %% [markdown]
# ## Now we do the check whether a row in lightning gave outage
#
# We do this via the following:
#
# The left_merged_df has all rows in lightning whether power outage or not
#
# The filtered_df has rows that gave rise to

# %%
# add a boolean column for the filter
left_merged_df['power_outage'] = left_merged_df.apply(lambda row: (row['_merge'] == 'both') and(str(row['county']) in str(row['Area Affected']) and str(row['state']) in str(row['Area Affected'])) or ((str(row['state']) in str(row['Area Affected']))and (not row['county_info_area_affected'])), axis=1)

# %%
left_merged_df[left_merged_df['power_outage']]
# Out:
#            #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT        location  \
# 127   2019-01-06     -123.4       47.3            1  (47.3, -123.4)
# 130   2019-01-06     -118.2       46.0            1  (46.0, -118.2)
# 133   2019-01-06     -123.2       47.0            2  (47.0, -123.2)
# 136   2019-01-06     -123.1       47.0            1  (47.0, -123.1)
# 196   2019-01-06     -118.1       45.9            1  (45.9, -118.1)
# ...          ...        ...        ...          ...             ...
# 60322 2019-11-01      -67.8       46.1            1   (46.1, -67.8)
# 60360 2019-11-01      -73.8       41.0            2   (41.0, -73.8)
# 60363 2019-11-01      -73.7       41.0            1   (41.0, -73.7)
# 60460 2019-11-01      -67.9       46.0            1   (46.0, -67.9)
# 61014 2019-11-27      -83.5       42.8            1   (42.8, -83.5)
#
#                     county       state     Month Date Event Began  \
# 127    Grays Harbor County  Washington   January       2019-01-06
# 130     Walla Walla County  Washington   January       2019-01-06
# 133    Grays Harbor County  Washington   January       2019-01-06
# 136    Grays Harbor County  Washington   January       2019-01-06
# 196     Walla Walla County  Washington   January       2019-01-06
# ...                    ...         ...       ...              ...
# 60322     Aroostook County       Maine  November       2019-11-01
# 60360   Westchester County    New York  November       2019-11-01
# 60363   Westchester County    New York  November       2019-11-01
# 60460     Aroostook County       Maine  November       2019-11-01
# 61014       Oakland County    Michigan  November       2019-11-27
#
#       Time Event Began  ... Time of Restoration  \
# 127           03:00:00  ...            07:00:00
# 130           03:00:00  ...            07:00:00
# 133           03:00:00  ...            07:00:00
# 136           03:00:00  ...            07:00:00
# 196           03:00:00  ...            07:00:00
# ...                ...  ...                 ...
# 60322         01:15:00  ...            21:30:00
# 60360         01:00:00  ...            13:00:00
# 60363         01:00:00  ...            13:00:00
# 60460         01:15:00  ...            21:30:00
# 61014         12:00:00  ...            02:00:00
#
#                                            Area Affected NERC Region  \
# 127                                          Washington:        WECC
# 130                                          Washington:        WECC
# 133                                          Washington:        WECC
# 136                                          Washington:        WECC
# 196                                          Washington:        WECC
# ...                                                  ...         ...
# 60322  Connecticut: Maine: Massachusetts: Rhode Islan...        NPCC
# 60360                                          New York:        NPCC
# 60363                                          New York:        NPCC
# 60460  Connecticut: Maine: Massachusetts: Rhode Islan...        NPCC
# 61014  Michigan: Tuscola County, Sanilac County, Huro...          RF
#
#                                           Alert Criteria      Event Type  \
# 127    Loss of electric service to more than 50,000 c...  Severe Weather
# 130    Loss of electric service to more than 50,000 c...  Severe Weather
# 133    Loss of electric service to more than 50,000 c...  Severe Weather
# 136    Loss of electric service to more than 50,000 c...  Severe Weather
# 196    Loss of electric service to more than 50,000 c...  Severe Weather
# ...                                                  ...             ...
# 60322  Loss of electric service to more than 50,000 c...  Severe Weather
# 60360  Loss of electric service to more than 50,000 c...  Severe Weather
# 60363  Loss of electric service to more than 50,000 c...  Severe Weather
# 60460  Loss of electric service to more than 50,000 c...  Severe Weather
# 61014  Loss of electric service to more than 50,000 c...  Severe Weather
#
#       Demand Loss (MW) Number of Customers Affected county_info_area_affected  \
# 127                230                       230000                     False
# 130                230                       230000                     False
# 133                230                       230000                     False
# 136                230                       230000                     False
# 196                230                       230000                     False
# ...                ...                          ...                       ...
# 60322          Unknown                        80066                     False
# 60360          Unknown                         8000                     False
# 60363          Unknown                         8000                     False
# 60460          Unknown                        80066                     False
# 61014               30                       107000                      True
#
#       _merge power_outage
# 127     both         True
# 130     both         True
# 133     both         True
# 136     both         True
# 196     both         True
# ...      ...          ...
# 60322   both         True
# 60360   both         True
# 60363   both         True
# 60460   both         True
# 61014   both         True
#
# [3084 rows x 21 columns]

# %% [markdown]
# ## We polish the dataframe by dropping unimportant columns

# %%
left_merged_df.columns.tolist()
# Out:
# ['#ZDAY',
#  'CENTERLON',
#  'CENTERLAT',
#  'TOTAL_COUNT',
#  'location',
#  'county',
#  'state',
#  'Month',
#  'Date Event Began',
#  'Time Event Began',
#  'Date of Restoration',
#  'Time of Restoration',
#  'Area Affected',
#  'NERC Region',
#  'Alert Criteria',
#  'Event Type',
#  'Demand Loss (MW)',
#  'Number of Customers Affected',
#  'county_info_area_affected',
#  '_merge',
#  'power_outage']

# %%
columns_to_drop = ['Month', 'Date Event Began', 'Time Event Began', 'Date of Restoration', 'Time of Restoration', 'Area Affected',
 'NERC Region','Alert Criteria', 'Event Type', 'Demand Loss (MW)', 'Number of Customers Affected', 'county_info_area_affected', '_merge']

lightning_outage = left_merged_df.copy()

lightning_outage = lightning_outage.drop(columns = columns_to_drop)

lightning_outage[lightning_outage["power_outage"]]
# Out:
#            #ZDAY  CENTERLON  CENTERLAT  TOTAL_COUNT        location  \
# 127   2019-01-06     -123.4       47.3            1  (47.3, -123.4)
# 130   2019-01-06     -118.2       46.0            1  (46.0, -118.2)
# 133   2019-01-06     -123.2       47.0            2  (47.0, -123.2)
# 136   2019-01-06     -123.1       47.0            1  (47.0, -123.1)
# 196   2019-01-06     -118.1       45.9            1  (45.9, -118.1)
# ...          ...        ...        ...          ...             ...
# 60322 2019-11-01      -67.8       46.1            1   (46.1, -67.8)
# 60360 2019-11-01      -73.8       41.0            2   (41.0, -73.8)
# 60363 2019-11-01      -73.7       41.0            1   (41.0, -73.7)
# 60460 2019-11-01      -67.9       46.0            1   (46.0, -67.9)
# 61014 2019-11-27      -83.5       42.8            1   (42.8, -83.5)
#
#                     county       state  power_outage
# 127    Grays Harbor County  Washington          True
# 130     Walla Walla County  Washington          True
# 133    Grays Harbor County  Washington          True
# 136    Grays Harbor County  Washington          True
# 196     Walla Walla County  Washington          True
# ...                    ...         ...           ...
# 60322     Aroostook County       Maine          True
# 60360   Westchester County    New York          True
# 60363   Westchester County    New York          True
# 60460     Aroostook County       Maine          True
# 61014       Oakland County    Michigan          True
#
# [3084 rows x 8 columns]

# %%
# save
#lightning_outage.to_csv('../merged/lightning_outage_2019.csv', index=False)
