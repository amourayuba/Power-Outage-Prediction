# %%
# import useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl 
mpl.rcParams["figure.dpi"] = 150
import seaborn as sns
import os
import datetime as dt
# enable copy on write (default in pandas 3.0)
pd.options.mode.copy_on_write = True

# %%
def read_merged(weather, year):
    return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))

# %% [markdown]
# # Using multiple years of tornados

# %%
meso = [read_merged("mesocyclone", year) for year in range(2015, 2024)]
# Out:
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))
# /tmp/ipykernel_17403/3053837900.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('../merged/merged_{}_{}.csv.gz'.format(weather, year))

# %%
data = pd.concat(meso)
del meso

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6247284 entries, 0 to 699146
# Data columns (total 20 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0      int64
#  1   index           int64
#  2   DATE            object
#  3   LAT_mean        float64
#  4   LON_mean        float64
#  5   STR_RANK_max    object
#  6   LL_ROT_VEL_max  int64
#  7   LL_DV_max       int64
#  8   LL_BASE_max     int64
#  9   DEPTH_KFT_max   int64
#  10  DPTH_STMRL_max  int64
#  11  MAX_RV_KFT_max  int64
#  12  MAX_RV_KTS_max  int64
#  13  TVS_max         object
#  14  MSI_max         int64
#  15  county          object
#  16  state           object
#  17  Month           object
#  18  power_outage    bool
#  19  Event Month     object
# dtypes: bool(1), float64(2), int64(10), object(7)
# memory usage: 959.2+ MB

# %%
data.sample(10)
# Out:
#         Unnamed: 0   index        DATE   LAT_mean    LON_mean STR_RANK_max  \
# 63019        63019   30298  2020-01-11  34.768040  -90.071147           7L
# 79789        79789   81149  2016-03-29  26.118930  -80.490050            5
# 64753        64753   63809  2015-04-13  41.972180  -96.181160           5L
# 490509      490509  440253  2017-09-11  30.637030  -83.217100            6
# 236926      236926  183900  2023-04-16  31.116800  -93.972590            3
# 206720      206720  152387  2023-04-01  42.179010  -87.120800            5
# 394200      394200  333810  2018-08-01  35.626410 -105.533142            6
# 144167      144167   79060  2020-02-10  33.307220 -116.858775           5L
# 357797      357797  327469  2022-06-15  44.983730  -90.909530            7
# 416072      416072  372044  2019-05-26  40.043515  -88.280655            8
#
#         LL_ROT_VEL_max  LL_DV_max  LL_BASE_max  DEPTH_KFT_max  DPTH_STMRL_max  \
# 63019               52        100           10             33             100
# 79789               32          0            9             12               0
# 64753               32         27            3             16              43
# 490509              37         55            9             12             100
# 236926              17         21           15             22              77
# 206720              29         28            9             16              97
# 394200              31         49           15             22             100
# 144167              38         38            2              5             100
# 357797              39         43           16             22              92
# 416072              43         77           11             18             100
#
#         MAX_RV_KFT_max  MAX_RV_KTS_max TVS_max  MSI_max             county  \
# 63019               10              52       N     5277     De Soto County
# 79789               17              35       N     3130     Broward County
# 64753                5              33       N     2759      Monona County
# 490509               9              37       N     3534      Echols County
# 236926              15              17       N     1288      Jasper County
# 206720              12              29       N     2574     LaPorte County
# 394200              25              31       N     2914  San Miguel County
# 144167               4              51       N     4319   Riverside County
# 357797              16              39       N     2905    Chippewa County
# 416072              11              43       N     3350   Champaign County
#
#               state      Month  power_outage Event Month
# 63019   Mississippi    January         False         NaN
# 79789       Florida        NaN         False         NaN
# 64753          Iowa        NaN         False         NaN
# 490509      Georgia  September          True         NaN
# 236926        Texas        NaN         False         NaN
# 206720      Indiana        NaN         False       April
# 394200   New Mexico        NaN         False         NaN
# 144167   California        NaN         False         NaN
# 357797    Wisconsin       June         False         NaN
# 416072     Illinois        NaN         False         NaN

# %%
data['TVS_max'].value_counts()
# Out:
# N    6203409
# Y      43875
# Name: TVS_max, dtype: int64

# %%
del data['Unnamed: 0']
del data['index']
del data['Event Month']
del data['Month']
data['TVS_max'] = 1*(data['TVS_max'] == 'Y')
data['DATE'] = pd.to_datetime(data['DATE'])
data['Month'] = data['DATE'].dt.month

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346371 entries, 0 to 39465
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DATE                  346371 non-null  datetime64[ns]
#  1   LAT_mean              346371 non-null  float64
#  2   LON_mean              346371 non-null  float64
#  3   AVGDV_max             346371 non-null  int64
#  4   LLDV_max              346371 non-null  int64
#  5   MXDV_max              346371 non-null  int64
#  6   MXDV_HEIGHT_max       346371 non-null  int64
#  7   DEPTH_max             346371 non-null  float64
#  8   MAX_SHEAR_max         346371 non-null  int64
#  9   MAX_SHEAR_HEIGHT_max  346371 non-null  float64
#  10  county                346371 non-null  object
#  11  state                 346371 non-null  object
#  12  Month                 346371 non-null  int64
#  13  power_outage          346371 non-null  bool
#  14  Event Month           7272 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(6), object(3)
# memory usage: 40.0+ MB

# %%
cols = data.columns
cols
# Out:
# Index(['DATE', 'LAT_mean', 'LON_mean', 'STR_RANK_max', 'LL_ROT_VEL_max',
#        'LL_DV_max', 'LL_BASE_max', 'DEPTH_KFT_max', 'DPTH_STMRL_max',
#        'MAX_RV_KFT_max', 'MAX_RV_KTS_max', 'TVS_max', 'MSI_max', 'county',
#        'state', 'power_outage', 'Month'],
#       dtype='object')

# %%
data['power_outage'].value_counts(normalize=True)
# Out:
# False    0.960052
# True     0.039948
# Name: power_outage, dtype: float64

# %%
features = ['LAT_mean', 'LON_mean', 'LL_ROT_VEL_max',
       'LL_DV_max', 'DPTH_STMRL_max', 'MAX_RV_KTS_max', 'TVS_max', 'MSI_max','Month']

# %%
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, make_scorer

# %%
meso_train, meso_test = train_test_split(data, test_size=0.2, stratify=data.power_outage)

# %%
meso_tt, meso_val = train_test_split(meso_train, test_size=0.2, stratify=meso_train.power_outage)

# %%
outage = meso_tt[meso_tt['power_outage']==True]
no_outage = meso_tt[meso_tt['power_outage']==False]
no_outage= no_outage.sample(n=10*len(outage), random_state=101)
balanced = pd.concat([outage,no_outage],axis=0)

# %%
model = xgboost.XGBClassifier(
    objective= 'binary:logistic', enable_categorical=True,
    seed=42)

parameters = {
    'max_depth': range (11, 17,  1),
    'n_estimators': range(200, 500, 20),
    'learning_rate': [0.01, 0.03]
}

# Grid search
# grid_search = GridSearchCV(model,
#     param_grid=parameters,
#     scoring='f1',
#     n_jobs=10,
#     cv = 3,
#     verbose=15)
# grid_search.fit(balanced[features], balanced['power_outage'])

# Randomized Search 
random_search = RandomizedSearchCV(model,
     param_distributions=parameters,
     n_iter=60,
     scoring='f1',
     refit = False,
     n_jobs=8,
     cv = 3,
     verbose=15)
random_search.fit(balanced[features], balanced['power_outage'])
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV 3/3; 2/60] START learning_rate=0.01, max_depth=13, n_estimators=260.........
# [CV 3/3; 2/60] END learning_rate=0.01, max_depth=13, n_estimators=260;, score=0.831 total time=  45.5s
# [CV 1/3; 6/60] START learning_rate=0.03, max_depth=14, n_estimators=420.........
# [CV 1/3; 6/60] END learning_rate=0.03, max_depth=14, n_estimators=420;, score=0.835 total time=  57.3s
# [CV 3/3; 8/60] START learning_rate=0.03, max_depth=14, n_estimators=260.........
# [CV 3/3; 8/60] END learning_rate=0.03, max_depth=14, n_estimators=260;, score=0.837 total time=  40.2s
# [CV 2/3; 11/60] START learning_rate=0.01, max_depth=12, n_estimators=240........
# [CV 2/3; 11/60] END learning_rate=0.01, max_depth=12, n_estimators=240;, score=0.827 total time=  29.9s
# [CV 1/3; 15/60] START learning_rate=0.01, max_depth=15, n_estimators=400........
# [CV 1/3; 15/60] END learning_rate=0.01, max_depth=15, n_estimators=400;, score=0.836 total time= 1.9min
# /home/painchess/.local/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 3/3; 1/60] START learning_rate=0.01, max_depth=13, n_estimators=200.........
# [CV 3/3; 1/60] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.826 total time=  37.4s
# [CV 2/3; 4/60] START learning_rate=0.03, max_depth=14, n_estimators=280.........
# [CV 2/3; 4/60] END learning_rate=0.03, max_depth=14, n_estimators=280;, score=0.836 total time=  41.1s
# [CV 1/3; 8/60] START learning_rate=0.03, max_depth=14, n_estimators=260.........
# [CV 1/3; 8/60] END learning_rate=0.03, max_depth=14, n_estimators=260;, score=0.836 total time=  40.5s
# [CV 3/3; 10/60] START learning_rate=0.01, max_depth=11, n_estimators=320........
# [CV 3/3; 10/60] END learning_rate=0.01, max_depth=11, n_estimators=320;, score=0.822 total time=  30.2s
# [CV 1/3; 13/60] START learning_rate=0.03, max_depth=12, n_estimators=320........
# [CV 1/3; 13/60] END learning_rate=0.03, max_depth=12, n_estimators=320;, score=0.833 total time=  28.2s
# [CV 3/3; 15/60] START learning_rate=0.01, max_depth=15, n_estimators=400........
# [CV 3/3; 15/60] END learning_rate=0.01, max_depth=15, n_estimators=400;, score=0.837 total time= 1.8min
# [CV 1/3; 2/60] START learning_rate=0.01, max_depth=13, n_estimators=260.........
# [CV 1/3; 2/60] END learning_rate=0.01, max_depth=13, n_estimators=260;, score=0.831 total time=  44.6s
# [CV 3/3; 5/60] START learning_rate=0.01, max_depth=12, n_estimators=200.........
# [CV 3/3; 5/60] END learning_rate=0.01, max_depth=12, n_estimators=200;, score=0.823 total time=  27.9s
# [CV 1/3; 7/60] START learning_rate=0.03, max_depth=14, n_estimators=220.........
# [CV 1/3; 7/60] END learning_rate=0.03, max_depth=14, n_estimators=220;, score=0.835 total time=  36.3s
# [CV 1/3; 9/60] START learning_rate=0.01, max_depth=12, n_estimators=300.........
# [CV 1/3; 9/60] END learning_rate=0.01, max_depth=12, n_estimators=300;, score=0.828 total time=  37.9s
# [CV 3/3; 11/60] START learning_rate=0.01, max_depth=12, n_estimators=240........
# [CV 3/3; 11/60] END learning_rate=0.01, max_depth=12, n_estimators=240;, score=0.826 total time=  30.6s
# [CV 2/3; 15/60] START learning_rate=0.01, max_depth=15, n_estimators=400........
# [CV 2/3; 15/60] END learning_rate=0.01, max_depth=15, n_estimators=400;, score=0.836 total time= 1.8min
# [CV 1/3; 19/60] START learning_rate=0.03, max_depth=14, n_estimators=460........
# [CV 1/3; 19/60] END learning_rate=0.03, max_depth=14, n_estimators=460;, score=0.835 total time=  56.9s
# [CV 2/3; 22/60] START learning_rate=0.01, max_depth=15, n_estimators=360........
# [CV 2/3; 22/60] END learning_rate=0.01, max_depth=15, n_estimators=360;, score=0.835 total time= 1.6min
# [CV 2/3; 3/60] START learning_rate=0.01, max_depth=11, n_estimators=380.........
# [CV 2/3; 3/60] END learning_rate=0.01, max_depth=11, n_estimators=380;, score=0.824 total time=  36.7s
# [CV 3/3; 4/60] START learning_rate=0.03, max_depth=14, n_estimators=280.........
# [CV 3/3; 4/60] END learning_rate=0.03, max_depth=14, n_estimators=280;, score=0.837 total time=  40.9s
# [CV 2/3; 8/60] START learning_rate=0.03, max_depth=14, n_estimators=260.........
# [CV 2/3; 8/60] END learning_rate=0.03, max_depth=14, n_estimators=260;, score=0.835 total time=  38.2s
# [CV 1/3; 10/60] START learning_rate=0.01, max_depth=11, n_estimators=320........
# [CV 1/3; 10/60] END learning_rate=0.01, max_depth=11, n_estimators=320;, score=0.823 total time=  30.6s
# [CV 1/3; 12/60] START learning_rate=0.03, max_depth=11, n_estimators=300........
# [CV 1/3; 12/60] END learning_rate=0.03, max_depth=11, n_estimators=300;, score=0.830 total time=  23.5s
# [CV 2/3; 14/60] START learning_rate=0.01, max_depth=12, n_estimators=320........
# [CV 2/3; 14/60] END learning_rate=0.01, max_depth=12, n_estimators=320;, score=0.829 total time=  48.1s
# [CV 1/3; 17/60] START learning_rate=0.03, max_depth=16, n_estimators=280........
# [CV 1/3; 17/60] END learning_rate=0.03, max_depth=16, n_estimators=280;, score=0.835 total time= 1.0min
# [CV 2/3; 18/60] START learning_rate=0.01, max_depth=11, n_estimators=420........
# [CV 2/3; 18/60] END learning_rate=0.01, max_depth=11, n_estimators=420;, score=0.824 total time=  35.6s
# [CV 3/3; 20/60] START learning_rate=0.01, max_depth=12, n_estimators=380........
# [CV 3/3; 20/60] END learning_rate=0.01, max_depth=12, n_estimators=380;, score=0.830 total time=  45.4s
# [CV 1/3; 24/60] START learning_rate=0.01, max_depth=13, n_estimators=420........
# [CV 1/3; 24/60] END learning_rate=0.01, max_depth=13, n_estimators=420;, score=0.834 total time= 1.1min
# [CV 3/3; 25/60] START learning_rate=0.01, max_depth=14, n_estimators=300........
# [CV 3/3; 25/60] END learning_rate=0.01, max_depth=14, n_estimators=300;, score=0.835 total time= 1.5min
# [CV 1/3; 20/60] START learning_rate=0.01, max_depth=12, n_estimators=380........
# [CV 1/3; 20/60] END learning_rate=0.01, max_depth=12, n_estimators=380;, score=0.830 total time=  48.5s
# [CV 1/3; 22/60] START learning_rate=0.01, max_depth=15, n_estimators=360........
# [CV 1/3; 22/60] END learning_rate=0.01, max_depth=15, n_estimators=360;, score=0.836 total time= 1.6min
# [CV 2/3; 26/60] START learning_rate=0.03, max_depth=11, n_estimators=460........
# [CV 2/3; 26/60] END learning_rate=0.03, max_depth=11, n_estimators=460;, score=0.830 total time=  40.6s
# [CV 2/3; 29/60] START learning_rate=0.03, max_depth=16, n_estimators=380........
# [CV 2/3; 29/60] END learning_rate=0.03, max_depth=16, n_estimators=380;, score=0.835 total time= 1.7min
# [CV 1/3; 1/60] START learning_rate=0.01, max_depth=13, n_estimators=200.........
# [CV 1/3; 1/60] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.829 total time=  37.0s
# [CV 1/3; 4/60] START learning_rate=0.03, max_depth=14, n_estimators=280.........
# [CV 1/3; 4/60] END learning_rate=0.03, max_depth=14, n_estimators=280;, score=0.836 total time=  39.3s
# [CV 3/3; 7/60] START learning_rate=0.03, max_depth=14, n_estimators=220.........
# [CV 3/3; 7/60] END learning_rate=0.03, max_depth=14, n_estimators=220;, score=0.837 total time=  35.1s
# [CV 3/3; 9/60] START learning_rate=0.01, max_depth=12, n_estimators=300.........
# [CV 3/3; 9/60] END learning_rate=0.01, max_depth=12, n_estimators=300;, score=0.828 total time=  38.7s
# [CV 2/3; 13/60] START learning_rate=0.03, max_depth=12, n_estimators=320........
# [CV 2/3; 13/60] END learning_rate=0.03, max_depth=12, n_estimators=320;, score=0.832 total time=  27.8s
# [CV 1/3; 16/60] START learning_rate=0.01, max_depth=13, n_estimators=460........
# [CV 1/3; 16/60] END learning_rate=0.01, max_depth=13, n_estimators=460;, score=0.833 total time= 1.4min
# [CV 3/3; 17/60] START learning_rate=0.03, max_depth=16, n_estimators=280........
# [CV 3/3; 17/60] END learning_rate=0.03, max_depth=16, n_estimators=280;, score=0.836 total time=  52.8s
# [CV 1/3; 21/60] START learning_rate=0.03, max_depth=12, n_estimators=420........
# [CV 1/3; 21/60] END learning_rate=0.03, max_depth=12, n_estimators=420;, score=0.833 total time=  31.2s
# [CV 2/3; 23/60] START learning_rate=0.03, max_depth=13, n_estimators=300........
# [CV 2/3; 23/60] END learning_rate=0.03, max_depth=13, n_estimators=300;, score=0.833 total time=  34.9s
# [CV 1/3; 25/60] START learning_rate=0.01, max_depth=14, n_estimators=300........
# [CV 1/3; 25/60] END learning_rate=0.01, max_depth=14, n_estimators=300;, score=0.835 total time= 1.2min
# [CV 1/3; 28/60] START learning_rate=0.01, max_depth=15, n_estimators=420........
# [CV 1/3; 28/60] END learning_rate=0.01, max_depth=15, n_estimators=420;, score=0.836 total time= 2.6min
# [CV 2/3; 1/60] START learning_rate=0.01, max_depth=13, n_estimators=200.........
# [CV 2/3; 1/60] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.827 total time=  36.4s
# [CV 3/3; 3/60] START learning_rate=0.01, max_depth=11, n_estimators=380.........
# [CV 3/3; 3/60] END learning_rate=0.01, max_depth=11, n_estimators=380;, score=0.824 total time=  37.2s
# [CV 2/3; 7/60] START learning_rate=0.03, max_depth=14, n_estimators=220.........
# [CV 2/3; 7/60] END learning_rate=0.03, max_depth=14, n_estimators=220;, score=0.835 total time=  36.4s
# [CV 2/3; 9/60] START learning_rate=0.01, max_depth=12, n_estimators=300.........
# [CV 2/3; 9/60] END learning_rate=0.01, max_depth=12, n_estimators=300;, score=0.829 total time=  37.7s
# [CV 2/3; 12/60] START learning_rate=0.03, max_depth=11, n_estimators=300........
# [CV 2/3; 12/60] END learning_rate=0.03, max_depth=11, n_estimators=300;, score=0.827 total time=  22.4s
# [CV 1/3; 14/60] START learning_rate=0.01, max_depth=12, n_estimators=320........
# [CV 1/3; 14/60] END learning_rate=0.01, max_depth=12, n_estimators=320;, score=0.829 total time=  46.3s
# [CV 3/3; 16/60] START learning_rate=0.01, max_depth=13, n_estimators=460........
# [CV 3/3; 16/60] END learning_rate=0.01, max_depth=13, n_estimators=460;, score=0.833 total time= 1.2min
# [CV 3/3; 19/60] START learning_rate=0.03, max_depth=14, n_estimators=460........
# [CV 3/3; 19/60] END learning_rate=0.03, max_depth=14, n_estimators=460;, score=0.835 total time=  52.1s
# [CV 3/3; 21/60] START learning_rate=0.03, max_depth=12, n_estimators=420........
# [CV 3/3; 21/60] END learning_rate=0.03, max_depth=12, n_estimators=420;, score=0.833 total time=  34.0s
# [CV 2/3; 24/60] START learning_rate=0.01, max_depth=13, n_estimators=420........
# [CV 2/3; 24/60] END learning_rate=0.01, max_depth=13, n_estimators=420;, score=0.833 total time= 1.0min
# [CV 1/3; 27/60] START learning_rate=0.01, max_depth=11, n_estimators=220........
# [CV 1/3; 27/60] END learning_rate=0.01, max_depth=11, n_estimators=220;, score=0.819 total time=  32.7s
# [CV 2/3; 28/60] START learning_rate=0.01, max_depth=15, n_estimators=420........
# [CV 2/3; 28/60] END learning_rate=0.01, max_depth=15, n_estimators=420;, score=0.836 total time= 2.6min
# [CV 2/3; 19/60] START learning_rate=0.03, max_depth=14, n_estimators=460........
# [CV 2/3; 19/60] END learning_rate=0.03, max_depth=14, n_estimators=460;, score=0.835 total time=  54.1s
# [CV 3/3; 22/60] START learning_rate=0.01, max_depth=15, n_estimators=360........
# [CV 3/3; 22/60] END learning_rate=0.01, max_depth=15, n_estimators=360;, score=0.837 total time= 1.5min
# [CV 1/3; 26/60] START learning_rate=0.03, max_depth=11, n_estimators=460........
# [CV 1/3; 26/60] END learning_rate=0.03, max_depth=11, n_estimators=460;, score=0.831 total time=  41.5s
# [CV 1/3; 29/60] START learning_rate=0.03, max_depth=16, n_estimators=380........
# [CV 1/3; 29/60] END learning_rate=0.03, max_depth=16, n_estimators=380;, score=0.834 total time= 1.8min
# [CV 1/3; 31/60] START learning_rate=0.01, max_depth=16, n_estimators=320........
# [CV 1/3; 31/60] END learning_rate=0.01, max_depth=16, n_estimators=320;, score=0.836 total time= 2.3min
# [CV 1/3; 3/60] START learning_rate=0.01, max_depth=11, n_estimators=380.........
# [CV 1/3; 3/60] END learning_rate=0.01, max_depth=11, n_estimators=380;, score=0.825 total time=  37.0s
# [CV 1/3; 5/60] START learning_rate=0.01, max_depth=12, n_estimators=200.........
# [CV 1/3; 5/60] END learning_rate=0.01, max_depth=12, n_estimators=200;, score=0.823 total time=  30.4s
# [CV 2/3; 6/60] START learning_rate=0.03, max_depth=14, n_estimators=420.........
# [CV 2/3; 6/60] END learning_rate=0.03, max_depth=14, n_estimators=420;, score=0.835 total time=  49.1s
# [CV 2/3; 10/60] START learning_rate=0.01, max_depth=11, n_estimators=320........
# [CV 2/3; 10/60] END learning_rate=0.01, max_depth=11, n_estimators=320;, score=0.822 total time=  31.8s
# [CV 3/3; 12/60] START learning_rate=0.03, max_depth=11, n_estimators=300........
# [CV 3/3; 12/60] END learning_rate=0.03, max_depth=11, n_estimators=300;, score=0.828 total time=  23.9s
# [CV 3/3; 14/60] START learning_rate=0.01, max_depth=12, n_estimators=320........
# [CV 3/3; 14/60] END learning_rate=0.01, max_depth=12, n_estimators=320;, score=0.829 total time=  47.0s
# [CV 2/3; 17/60] START learning_rate=0.03, max_depth=16, n_estimators=280........
# [CV 2/3; 17/60] END learning_rate=0.03, max_depth=16, n_estimators=280;, score=0.835 total time= 1.0min
# [CV 3/3; 18/60] START learning_rate=0.01, max_depth=11, n_estimators=420........
# [CV 3/3; 18/60] END learning_rate=0.01, max_depth=11, n_estimators=420;, score=0.825 total time=  38.9s
# [CV 2/3; 21/60] START learning_rate=0.03, max_depth=12, n_estimators=420........
# [CV 2/3; 21/60] END learning_rate=0.03, max_depth=12, n_estimators=420;, score=0.833 total time=  29.5s
# [CV 3/3; 23/60] START learning_rate=0.03, max_depth=13, n_estimators=300........
# [CV 3/3; 23/60] END learning_rate=0.03, max_depth=13, n_estimators=300;, score=0.834 total time=  33.6s
# [CV 2/3; 25/60] START learning_rate=0.01, max_depth=14, n_estimators=300........
# [CV 2/3; 25/60] END learning_rate=0.01, max_depth=14, n_estimators=300;, score=0.834 total time= 1.1min
# [CV 3/3; 27/60] START learning_rate=0.01, max_depth=11, n_estimators=220........
# [CV 3/3; 27/60] END learning_rate=0.01, max_depth=11, n_estimators=220;, score=0.817 total time=  34.4s
# [CV 3/3; 29/60] START learning_rate=0.03, max_depth=16, n_estimators=380........
# [CV 3/3; 29/60] END learning_rate=0.03, max_depth=16, n_estimators=380;, score=0.835 total time= 1.8min
# [CV 3/3; 31/60] START learning_rate=0.01, max_depth=16, n_estimators=320........
# [CV 3/3; 31/60] END learning_rate=0.01, max_depth=16, n_estimators=320;, score=0.837 total time= 2.3min
# [CV 2/3; 30/60] START learning_rate=0.01, max_depth=12, n_estimators=460........
# [CV 2/3; 30/60] END learning_rate=0.01, max_depth=12, n_estimators=460;, score=0.830 total time= 1.3min
# [CV 1/3; 32/60] START learning_rate=0.01, max_depth=15, n_estimators=460........
# [CV 1/3; 32/60] END learning_rate=0.01, max_depth=15, n_estimators=460;, score=0.836 total time= 2.2min
# [CV 2/3; 35/60] START learning_rate=0.03, max_depth=16, n_estimators=440........
# [CV 2/3; 35/60] END learning_rate=0.03, max_depth=16, n_estimators=440;, score=0.834 total time= 1.4min
# [CV 1/3; 34/60] START learning_rate=0.03, max_depth=11, n_estimators=280........
# [CV 1/3; 34/60] END learning_rate=0.03, max_depth=11, n_estimators=280;, score=0.829 total time=  14.3s
# [CV 3/3; 35/60] START learning_rate=0.03, max_depth=16, n_estimators=440........
# [CV 3/3; 35/60] END learning_rate=0.03, max_depth=16, n_estimators=440;, score=0.835 total time= 1.3min
# [CV 1/3; 40/60] START learning_rate=0.01, max_depth=11, n_estimators=260........
# [CV 1/3; 40/60] END learning_rate=0.01, max_depth=11, n_estimators=260;, score=0.822 total time=  29.1s
# [CV 3/3; 40/60] START learning_rate=0.01, max_depth=11, n_estimators=260........
# [CV 3/3; 40/60] END learning_rate=0.01, max_depth=11, n_estimators=260;, score=0.819 total time=  24.4s
# [CV 3/3; 41/60] START learning_rate=0.03, max_depth=11, n_estimators=420........
# [CV 3/3; 41/60] END learning_rate=0.03, max_depth=11, n_estimators=420;, score=0.830 total time=  29.1s
# [CV 2/3; 43/60] START learning_rate=0.03, max_depth=12, n_estimators=340........
# [CV 2/3; 43/60] END learning_rate=0.03, max_depth=12, n_estimators=340;, score=0.833 total time=  23.1s
# [CV 1/3; 46/60] START learning_rate=0.01, max_depth=14, n_estimators=440........
# [CV 1/3; 46/60] END learning_rate=0.01, max_depth=14, n_estimators=440;, score=0.836 total time= 1.6min
# [CV 2/3; 40/60] START learning_rate=0.01, max_depth=11, n_estimators=260........
# [CV 2/3; 40/60] END learning_rate=0.01, max_depth=11, n_estimators=260;, score=0.820 total time=  29.3s
# [CV 1/3; 41/60] START learning_rate=0.03, max_depth=11, n_estimators=420........
# [CV 1/3; 41/60] END learning_rate=0.03, max_depth=11, n_estimators=420;, score=0.831 total time=  29.3s
# [CV 3/3; 42/60] START learning_rate=0.01, max_depth=11, n_estimators=360........
# [CV 3/3; 42/60] END learning_rate=0.01, max_depth=11, n_estimators=360;, score=0.823 total time=  29.9s
# [CV 3/3; 45/60] START learning_rate=0.03, max_depth=14, n_estimators=320........
# [CV 3/3; 45/60] END learning_rate=0.03, max_depth=14, n_estimators=320;, score=0.837 total time=  47.1s
# [CV 3/3; 46/60] START learning_rate=0.01, max_depth=14, n_estimators=440........
# [CV 3/3; 46/60] END learning_rate=0.01, max_depth=14, n_estimators=440;, score=0.836 total time= 1.4min
# [CV 2/3; 2/60] START learning_rate=0.01, max_depth=13, n_estimators=260.........
# [CV 2/3; 2/60] END learning_rate=0.01, max_depth=13, n_estimators=260;, score=0.830 total time=  43.6s
# [CV 2/3; 5/60] START learning_rate=0.01, max_depth=12, n_estimators=200.........
# [CV 2/3; 5/60] END learning_rate=0.01, max_depth=12, n_estimators=200;, score=0.825 total time=  28.4s
# [CV 3/3; 6/60] START learning_rate=0.03, max_depth=14, n_estimators=420.........
# [CV 3/3; 6/60] END learning_rate=0.03, max_depth=14, n_estimators=420;, score=0.836 total time=  50.0s
# [CV 1/3; 11/60] START learning_rate=0.01, max_depth=12, n_estimators=240........
# [CV 1/3; 11/60] END learning_rate=0.01, max_depth=12, n_estimators=240;, score=0.825 total time=  29.8s
# [CV 3/3; 13/60] START learning_rate=0.03, max_depth=12, n_estimators=320........
# [CV 3/3; 13/60] END learning_rate=0.03, max_depth=12, n_estimators=320;, score=0.832 total time=  27.3s
# [CV 2/3; 16/60] START learning_rate=0.01, max_depth=13, n_estimators=460........
# [CV 2/3; 16/60] END learning_rate=0.01, max_depth=13, n_estimators=460;, score=0.833 total time= 1.4min
# [CV 1/3; 18/60] START learning_rate=0.01, max_depth=11, n_estimators=420........
# [CV 1/3; 18/60] END learning_rate=0.01, max_depth=11, n_estimators=420;, score=0.825 total time=  33.1s
# [CV 2/3; 20/60] START learning_rate=0.01, max_depth=12, n_estimators=380........
# [CV 2/3; 20/60] END learning_rate=0.01, max_depth=12, n_estimators=380;, score=0.830 total time=  45.1s
# [CV 1/3; 23/60] START learning_rate=0.03, max_depth=13, n_estimators=300........
# [CV 1/3; 23/60] END learning_rate=0.03, max_depth=13, n_estimators=300;, score=0.835 total time=  36.0s
# [CV 3/3; 24/60] START learning_rate=0.01, max_depth=13, n_estimators=420........
# [CV 3/3; 24/60] END learning_rate=0.01, max_depth=13, n_estimators=420;, score=0.833 total time= 1.0min
# [CV 2/3; 27/60] START learning_rate=0.01, max_depth=11, n_estimators=220........
# [CV 2/3; 27/60] END learning_rate=0.01, max_depth=11, n_estimators=220;, score=0.816 total time=  33.2s
# [CV 3/3; 28/60] START learning_rate=0.01, max_depth=15, n_estimators=420........
# [CV 3/3; 28/60] END learning_rate=0.01, max_depth=15, n_estimators=420;, score=0.837 total time= 2.6min
# [CV 1/3; 33/60] START learning_rate=0.01, max_depth=13, n_estimators=400........
# [CV 1/3; 33/60] END learning_rate=0.01, max_depth=13, n_estimators=400;, score=0.833 total time= 1.4min
# [CV 3/3; 33/60] START learning_rate=0.01, max_depth=13, n_estimators=400........
# [CV 3/3; 33/60] END learning_rate=0.01, max_depth=13, n_estimators=400;, score=0.833 total time= 1.0min
# [CV 2/3; 37/60] START learning_rate=0.03, max_depth=11, n_estimators=400........
# [CV 2/3; 37/60] END learning_rate=0.03, max_depth=11, n_estimators=400;, score=0.830 total time=  28.5s
# [CV 1/3; 39/60] START learning_rate=0.03, max_depth=16, n_estimators=220........
# [CV 1/3; 39/60] END learning_rate=0.03, max_depth=16, n_estimators=220;, score=0.835 total time= 1.0min
# [CV 2/3; 41/60] START learning_rate=0.03, max_depth=11, n_estimators=420........
# [CV 2/3; 41/60] END learning_rate=0.03, max_depth=11, n_estimators=420;, score=0.830 total time=  29.2s
# [CV 1/3; 43/60] START learning_rate=0.03, max_depth=12, n_estimators=340........
# [CV 1/3; 43/60] END learning_rate=0.03, max_depth=12, n_estimators=340;, score=0.833 total time=  22.6s
# [CV 2/3; 45/60] START learning_rate=0.03, max_depth=14, n_estimators=320........
# [CV 2/3; 45/60] END learning_rate=0.03, max_depth=14, n_estimators=320;, score=0.836 total time=  49.9s
# [CV 2/3; 47/60] START learning_rate=0.01, max_depth=15, n_estimators=440........
# [CV 2/3; 47/60] END learning_rate=0.01, max_depth=15, n_estimators=440;, score=0.835 total time= 1.8min
# [CV 3/3; 26/60] START learning_rate=0.03, max_depth=11, n_estimators=460........
# [CV 3/3; 26/60] END learning_rate=0.03, max_depth=11, n_estimators=460;, score=0.830 total time=  49.4s
# [CV 1/3; 30/60] START learning_rate=0.01, max_depth=12, n_estimators=460........
# [CV 1/3; 30/60] END learning_rate=0.01, max_depth=12, n_estimators=460;, score=0.830 total time= 1.4min
# [CV 3/3; 30/60] START learning_rate=0.01, max_depth=12, n_estimators=460........
# [CV 3/3; 30/60] END learning_rate=0.01, max_depth=12, n_estimators=460;, score=0.830 total time= 1.2min
# [CV 2/3; 33/60] START learning_rate=0.01, max_depth=13, n_estimators=400........
# [CV 2/3; 33/60] END learning_rate=0.01, max_depth=13, n_estimators=400;, score=0.833 total time= 1.2min
# [CV 2/3; 34/60] START learning_rate=0.03, max_depth=11, n_estimators=280........
# [CV 2/3; 34/60] END learning_rate=0.03, max_depth=11, n_estimators=280;, score=0.827 total time=  14.9s
# [CV 1/3; 36/60] START learning_rate=0.01, max_depth=12, n_estimators=360........
# [CV 1/3; 36/60] END learning_rate=0.01, max_depth=12, n_estimators=360;, score=0.829 total time=  52.1s
# [CV 3/3; 37/60] START learning_rate=0.03, max_depth=11, n_estimators=400........
# [CV 3/3; 37/60] END learning_rate=0.03, max_depth=11, n_estimators=400;, score=0.830 total time=  26.3s
# [CV 3/3; 39/60] START learning_rate=0.03, max_depth=16, n_estimators=220........
# [CV 3/3; 39/60] END learning_rate=0.03, max_depth=16, n_estimators=220;, score=0.836 total time=  55.5s
# [CV 2/3; 42/60] START learning_rate=0.01, max_depth=11, n_estimators=360........
# [CV 2/3; 42/60] END learning_rate=0.01, max_depth=11, n_estimators=360;, score=0.823 total time=  33.1s
# [CV 1/3; 44/60] START learning_rate=0.01, max_depth=14, n_estimators=420........
# [CV 1/3; 44/60] END learning_rate=0.01, max_depth=14, n_estimators=420;, score=0.836 total time= 1.5min
# [CV 3/3; 47/60] START learning_rate=0.01, max_depth=15, n_estimators=440........
# [CV 3/3; 47/60] END learning_rate=0.01, max_depth=15, n_estimators=440;, score=0.837 total time= 1.9min
# [CV 3/3; 32/60] START learning_rate=0.01, max_depth=15, n_estimators=460........
# [CV 3/3; 32/60] END learning_rate=0.01, max_depth=15, n_estimators=460;, score=0.837 total time= 2.1min
# [CV 1/3; 37/60] START learning_rate=0.03, max_depth=11, n_estimators=400........
# [CV 1/3; 37/60] END learning_rate=0.03, max_depth=11, n_estimators=400;, score=0.831 total time=  28.7s
# [CV 2/3; 38/60] START learning_rate=0.01, max_depth=16, n_estimators=400........
# [CV 2/3; 38/60] END learning_rate=0.01, max_depth=16, n_estimators=400;, score=0.836 total time= 2.1min
# [CV 2/3; 44/60] START learning_rate=0.01, max_depth=14, n_estimators=420........
# [CV 2/3; 44/60] END learning_rate=0.01, max_depth=14, n_estimators=420;, score=0.835 total time= 1.6min
# [CV 2/3; 48/60] START learning_rate=0.01, max_depth=16, n_estimators=440........
# [CV 2/3; 48/60] END learning_rate=0.01, max_depth=16, n_estimators=440;, score=0.836 total time= 2.2min
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=True,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=...
#                                            max_delta_step=None, max_depth=None,
#                                            max_leaves=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_iter=60, n_jobs=8,
#                    param_distributions={'learning_rate': [0.01, 0.03],
#                                         'max_depth': range(11, 17),
#                                         'n_estimators': range(200, 500, 20)},
#                    refit=False, scoring='f1', verbose=15)

# %%
grid_search.estimator
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
#res = grid_search.cv_results_
res = random_search.cv_results_

pars = [tuple(par.values()) for par in res['params']]
scores = np.array(res['mean_test_score'])
param_scores = dict(zip(pars, scores))
param_scores
# Out:
# {(200, 13, 0.01): 0.8272275558116341,
#  (260, 13, 0.01): 0.8305829563387283,
#  (380, 11, 0.01): 0.8240990499270914,
#  (280, 14, 0.03): 0.8359596034939564,
#  (200, 12, 0.01): 0.8236362352231299,
#  (420, 14, 0.03): 0.8353393637435663,
#  (220, 14, 0.03): 0.8357707196252703,
#  (260, 14, 0.03): 0.8359136638212502,
#  (300, 12, 0.01): 0.8281109198993398,
#  (320, 11, 0.01): 0.822529407315312,
#  (240, 12, 0.01): 0.8258398551355287,
#  (300, 11, 0.03): 0.8284166533186835,
#  (320, 12, 0.03): 0.8324589018087387,
#  (320, 12, 0.01): 0.82878739491567,
#  (400, 15, 0.01): 0.8360755623496404,
#  (460, 13, 0.01): 0.833377823266952,
#  (280, 16, 0.03): 0.8353542070514784,
#  (420, 11, 0.01): 0.8248131472523378,
#  (460, 14, 0.03): 0.8350076441083482,
#  (380, 12, 0.01): 0.8298533594291103,
#  (420, 12, 0.03): 0.8329974055710903,
#  (360, 15, 0.01): 0.8358256592232381,
#  (300, 13, 0.03): 0.8341885188007855,
#  (420, 13, 0.01): 0.8332523287825694,
#  (300, 14, 0.01): 0.8345913819207258,
#  (460, 11, 0.03): 0.8305719177445089,
#  (220, 11, 0.01): 0.8175313082444626,
#  (420, 15, 0.01): 0.8361567337299457,
#  (380, 16, 0.03): 0.8346373211914587,
#  (460, 12, 0.01): 0.8301200598100098,
#  (320, 16, 0.01): 0.8360584259937166,
#  (460, 15, 0.01): 0.8362239747522163,
#  (400, 13, 0.01): 0.8331587937431428,
#  (280, 11, 0.03): 0.8281892800289747,
#  (440, 16, 0.03): 0.8342183760674352,
#  (360, 12, 0.01): 0.8295047533134671,
#  (400, 11, 0.03): 0.8302097011983559,
#  (400, 16, 0.01): 0.8363173116260612,
#  (220, 16, 0.03): 0.8355500963008269,
#  (260, 11, 0.01): 0.8202029647381396,
#  (420, 11, 0.03): 0.8303138682101595,
#  (360, 11, 0.01): 0.8236577583042722,
#  (340, 12, 0.03): 0.832582724620079,
#  (420, 14, 0.01): 0.8356127827578314,
#  (320, 14, 0.03): 0.8359226718106932,
#  (440, 14, 0.01): 0.835730662887589,
#  (440, 15, 0.01): 0.8361478717057675,
#  (440, 16, 0.01): 0.8363920855377295,
#  (360, 13, 0.03): 0.8343204956763364,
#  (220, 16, 0.01): 0.8339750180823496,
#  (340, 15, 0.03): 0.835737364883529,
#  (240, 14, 0.03): 0.8358304541528804,
#  (400, 11, 0.01): 0.8244917455798045,
#  (440, 15, 0.03): 0.8351423603382083,
#  (260, 15, 0.01): 0.8342629656111105,
#  (420, 15, 0.03): 0.8351323712091968,
#  (440, 11, 0.01): 0.8250046216669951,
#  (360, 14, 0.01): 0.8353990981411975,
#  (460, 14, 0.01): 0.8356774382559046,
#  (240, 15, 0.03): 0.8362956064441542}

# %%
#grid_search.best_params_
random_search.best_params_
# Out:
# {'n_estimators': 440, 'max_depth': 16, 'learning_rate': 0.01}

# %%
best_model = xgboost.XGBClassifier(
    objective= 'binary:logistic', learning_rate=0.01, max_depth=16, n_estimators=440)
best_model.fit(balanced[features], balanced['power_outage'])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=16, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=440, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
prec = precision_score(best_model.predict(meso_val[features]), meso_val['power_outage'])
recall = recall_score(best_model.predict(meso_val[features]), meso_val['power_outage'])
print("precision: ", prec)
print("recall: ", recall)
# Out:
# precision:  0.2449725776965265
# recall:  0.4218015609503687

# %%
best_model.get_booster().get_score(importance_type='gain')
# Out:
# {'LAT_mean': 11.998180389404297,
#  'LON_mean': 16.021921157836914,
#  'LL_ROT_VEL_max': 2.2873291969299316,
#  'LL_DV_max': 2.319385528564453,
#  'DPTH_STMRL_max': 6.398529529571533,
#  'MAX_RV_KTS_max': 2.8266963958740234,
#  'TVS_max': 4.625914096832275,
#  'MSI_max': 2.6701462268829346,
#  'Month': 35.68828582763672}

# %%
from sklearn.metrics import PrecisionRecallDisplay

display = PrecisionRecallDisplay.from_estimator(
    best_model, meso_val[features], meso_val['power_outage'], name="xGBoost")
_ = display.ax_.set_title("2-class Precision-Recall curve")

# %%
from sklearn.metrics import PrecisionRecallDisplay

display = PrecisionRecallDisplay.from_estimator(
    best_model, meso_val[features], meso_val['power_outage'], name="xGBoost")
_ = display.ax_.set_title("2-class Precision-Recall curve")
